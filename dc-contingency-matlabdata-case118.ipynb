# %%
# install package

using Pkg
Pkg.instantiate()
import Pkg
Pkg.add("TimeZones")
using PowerModels
Pkg.activate(".")
Pkg.status()

Pkg.add("Xpress")
Pkg.add("JSON")
Pkg.add("JuMP")
Pkg.add("Ipopt")
Pkg.add("InfrastructureModels")
Pkg.add("PowerModels")
Pkg.add("Memento")


using Xpress

time_start = time()
println("start pre-compilation")

using Distributed
using SparseArrays


using JSON

using JuMP

using Ipopt

using InfrastructureModels
using PowerModels
using Memento

const LOGGER = getlogger("GOC")

import Statistics: mean

println("pre-compilation finished ($(time() - time_start))")
# Out:
#   Resolving package versions...
# Status `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Project.toml`
#   [2030c09a] InfrastructureModels v0.5.3
#   [b6b21f68] Ipopt v0.6.3
#   [682c06a0] JSON v0.21.0
#   [4076af6c] JuMP v0.21.3
#   [f28f55f0] Memento v1.1.1
#   [c36e90e8] PowerModels v0.17.2
#   [f269a46b] TimeZones v1.3.2
#   [9e70acf3] Xpress v0.11.0
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Project.toml`
#  [no changes]
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Manifest.toml`
#  [no changes]
#  Activating environment at `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Project.toml`
#   Resolving package versions...
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Project.toml`
#  [no changes]
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Manifest.toml`
#  [no changes]
#   Resolving package versions...
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Project.toml`
#  [no changes]
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Manifest.toml`
#  [no changes]
#   Resolving package versions...
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Project.toml`
#  [no changes]
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Manifest.toml`
#  [no changes]
#   Resolving package versions...
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Project.toml`
#  [no changes]
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Manifest.toml`
#  [no changes]
#   Resolving package versions...
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Project.toml`
#  [no changes]
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Manifest.toml`
#  [no changes]
#   Resolving package versions...
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Project.toml`
#  [no changes]
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Manifest.toml`
#  [no changes]
#   Resolving package versions...
# start pre-compilation
# pre-compilation finished (0.04200005531311035)
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Project.toml`
#  [no changes]
#    Updating `C:\Users\Rita\Desktop\Project - code-RUODAN WANG\Manifest.toml`
#  [no changes]

# %%
# dataset
case = "case118.m"
# transform data
case_data= parse_matpower(case)
# using IPOPT (interior point method) as ptimial probelm solver
solver = JuMP.with_optimizer(Ipopt.Optimizer, tol=1e-9, print_level=0)
# solve basic DCOPF model
result_base = run_opf(case_data,DCPPowerModel, solver)
# Out:
# [warn | PowerModels]: the voltage setpoint on generator 43 does not match the value at bus 92
# [warn | PowerModels]: the voltage setpoint on generator 9 does not match the value at bus 19
# [warn | PowerModels]: the voltage setpoint on generator 15 does not match the value at bus 32
# [warn | PowerModels]: the voltage setpoint on generator 16 does not match the value at bus 34
# [warn | PowerModels]: the voltage setpoint on generator 46 does not match the value at bus 103
# Dict{String,Any} with 8 entries:
#   "solve_time"         => 0.0539999
#   "optimizer"          => "Ipopt"
#   "termination_status" => LOCALLY_SOLVED
#   "dual_status"        => FEASIBLE_POINT
#   "primal_status"      => FEASIBLE_POINT
#   "objective"          => 125948.0
#   "solution"           => Dict{String,Any}("baseMVA"=>100,"branch"=>Dict{String…
#   "objective_lb"       => -Inf

# %%
# basic solution value of real power generation
result_base["solution"]["gen"]
# Out:
# Dict{String,Any} with 54 entries:
#   "32" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "29" => Dict{String,Any}("qg"=>NaN,"pg"=>3.79875)
#   "1"  => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "54" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "2"  => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "41" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "51" => Dict{String,Any}("qg"=>NaN,"pg"=>0.348864)
#   "53" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "27" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "42" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "33" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "28" => Dict{String,Any}("qg"=>NaN,"pg"=>3.78906)
#   "52" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "50" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "26" => Dict{String,Any}("qg"=>NaN,"pg"=>1.55051)
#   "10" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "24" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "25" => Dict{String,Any}("qg"=>NaN,"pg"=>1.50206)
#   "23" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "49" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "31" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "5"  => Dict{String,Any}("qg"=>NaN,"pg"=>4.36081)
#   "43" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   "39" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0387627)
#   "44" => Dict{String,Any}("qg"=>NaN,"pg"=>0.0)
#   ⋮    => ⋮

# %%
# basic value of voltage phase
result_base["solution"]["bus"]
# Out:
# Dict{String,Any} with 118 entries:
#   "109" => Dict{String,Any}("va"=>-0.205728,"vm"=>1.0)
#   "29"  => Dict{String,Any}("va"=>-0.303947,"vm"=>1.0)
#   "1"   => Dict{String,Any}("va"=>-0.336724,"vm"=>1.0)
#   "78"  => Dict{String,Any}("va"=>-0.0755429,"vm"=>1.0)
#   "54"  => Dict{String,Any}("va"=>-0.274716,"vm"=>1.0)
#   "32"  => Dict{String,Any}("va"=>-0.268839,"vm"=>1.0)
#   "101" => Dict{String,Any}("va"=>-0.0197168,"vm"=>1.0)
#   "2"   => Dict{String,Any}("va"=>-0.324149,"vm"=>1.0)
#   "3"   => Dict{String,Any}("va"=>-0.318439,"vm"=>1.0)
#   "81"  => Dict{String,Any}("va"=>-0.0378746,"vm"=>1.0)
#   "74"  => Dict{String,Any}("va"=>-0.164698,"vm"=>1.0)
#   "41"  => Dict{String,Any}("va"=>-0.405457,"vm"=>1.0)
#   "65"  => Dict{String,Any}("va"=>-0.0451459,"vm"=>1.0)
#   "51"  => Dict{String,Any}("va"=>-0.256695,"vm"=>1.0)
#   "53"  => Dict{String,Any}("va"=>-0.291718,"vm"=>1.0)
#   "106" => Dict{String,Any}("va"=>-0.184525,"vm"=>1.0)
#   "27"  => Dict{String,Any}("va"=>-0.258572,"vm"=>1.0)
#   "75"  => Dict{String,Any}("va"=>-0.141893,"vm"=>1.0)
#   "42"  => Dict{String,Any}("va"=>-0.375625,"vm"=>1.0)
#   "33"  => Dict{String,Any}("va"=>-0.336651,"vm"=>1.0)
#   "28"  => Dict{String,Any}("va"=>-0.288061,"vm"=>1.0)
#   "52"  => Dict{String,Any}("va"=>-0.274913,"vm"=>1.0)
#   "50"  => Dict{String,Any}("va"=>-0.203479,"vm"=>1.0)
#   "111" => Dict{String,Any}("va"=>-0.188964,"vm"=>1.0)
#   "63"  => Dict{String,Any}("va"=>-0.136294,"vm"=>1.0)
#   ⋮     => ⋮

# %%
PowerModels.print_summary(case_data)
# Out:
# Metadata
#   baseMVA: 100
#   name: case118
#   per_unit: true
#   source_type: matpower
#   source_version: 2
#
# Table Counts
#   bus: 118
#   load: 99
#   shunt: 14
#   gen: 54
#   storage: 0
#   switch: 0
#   branch: 186
#   dcline: 0
#
#
# Table: bus
#          bus_i, base_kv, bus_type,    vm,    va
#       1:     1, 138.000,        2, 0.955, 0.186
#       2:     2, 138.000,        1, 0.971, 0.196
#       3:     3, 138.000,        1, 0.968, 0.202
#       4:     4, 138.000,        2, 0.998, 0.267
#       5:     5, 138.000,        1, 1.002, 0.275
#       6:     6, 138.000,        2, 0.990, 0.227
#       7:     7, 138.000,        1, 0.989, 0.219
#       8:     8, 345.000,        2, 1.015, 0.363
#       9:     9, 345.000,        1, 1.043, 0.489
#      10:    10, 345.000,        2, 1.050, 0.622
#      11:    11, 138.000,        1, 0.985, 0.222
#      12:    12, 138.000,        2, 0.990, 0.213
#      13:    13, 138.000,        1, 0.968, 0.198
#      14:    14, 138.000,        1, 0.984, 0.201
#      15:    15, 138.000,        2, 0.970, 0.196
#      16:    16, 138.000,        1, 0.984, 0.208
#      17:    17, 138.000,        1, 0.995, 0.240
#      18:    18, 138.000,        2, 0.973, 0.201
#      19:    19, 138.000,        2, 0.963, 0.193
#      20:    20, 138.000,        1, 0.958, 0.208
#      21:    21, 138.000,        1, 0.959, 0.236
#      22:    22, 138.000,        1, 0.970, 0.281
#      23:    23, 138.000,        1, 1.000, 0.367
#      24:    24, 138.000,        2, 0.992, 0.365
#      25:    25, 138.000,        2, 1.050, 0.487
#      26:    26, 345.000,        2, 1.015, 0.519
#      27:    27, 138.000,        2, 0.968, 0.268
#      28:    28, 138.000,        1, 0.962, 0.238
#      29:    29, 138.000,        1, 0.963, 0.220
#      30:    30, 345.000,        1, 0.968, 0.328
#      31:    31, 138.000,        2, 0.967, 0.223
#      32:    32, 138.000,        2, 0.964, 0.258
#      33:    33, 138.000,        1, 0.972, 0.186
#      34:    34, 138.000,        2, 0.986, 0.197
#      35:    35, 138.000,        1, 0.981, 0.190
#      36:    36, 138.000,        2, 0.980, 0.190
#      37:    37, 138.000,        1, 0.992, 0.205
#      38:    38, 345.000,        1, 0.962, 0.295
#      39:    39, 138.000,        1, 0.970, 0.147
#      40:    40, 138.000,        2, 0.970, 0.128
#      41:    41, 138.000,        1, 0.967, 0.121
#      42:    42, 138.000,        2, 0.985, 0.149
#      43:    43, 138.000,        1, 0.978, 0.197
#      44:    44, 138.000,        1, 0.985, 0.241
#      45:    45, 138.000,        1, 0.987, 0.273
#      46:    46, 138.000,        2, 1.005, 0.323
#      47:    47, 138.000,        1, 1.017, 0.362
#      48:    48, 138.000,        1, 1.021, 0.348
#      49:    49, 138.000,        2, 1.025, 0.365
#      50:    50, 138.000,        1, 1.001, 0.330
#      51:    51, 138.000,        1, 0.967, 0.284
#      52:    52, 138.000,        1, 0.957, 0.267
#      53:    53, 138.000,        1, 0.946, 0.250
#      54:    54, 138.000,        2, 0.955, 0.266
#      55:    55, 138.000,        2, 0.952, 0.261
#      56:    56, 138.000,        2, 0.954, 0.265
#      57:    57, 138.000,        1, 0.971, 0.286
#      58:    58, 138.000,        1, 0.959, 0.271
#      59:    59, 138.000,        2, 0.985, 0.338
#      60:    60, 138.000,        1, 0.993, 0.404
#      61:    61, 138.000,        2, 0.995, 0.420
#      62:    62, 138.000,        2, 0.998, 0.409
#      63:    63, 345.000,        1, 0.969, 0.397
#      64:    64, 345.000,        1, 0.984, 0.428
#      65:    65, 345.000,        2, 1.005, 0.483
#      66:    66, 138.000,        2, 1.050, 0.480
#      67:    67, 138.000,        1, 1.020, 0.434
#      68:    68, 345.000,        1, 1.003, 0.481
#      69:    69, 138.000,        3, 1.035, 0.524
#      70:    70, 138.000,        2, 0.984, 0.394
#      71:    71, 138.000,        1, 0.987, 0.387
#      72:    72, 138.000,        2, 0.980, 0.366
#      73:    73, 138.000,        2, 0.991, 0.383
#      74:    74, 138.000,        2, 0.958, 0.378
#      75:    75, 138.000,        1, 0.967, 0.400
#      76:    76, 138.000,        2, 0.943, 0.380
#      77:    77, 138.000,        2, 1.006, 0.466
#      78:    78, 138.000,        1, 1.003, 0.461
#      79:    79, 138.000,        1, 1.009, 0.466
#      80:    80, 138.000,        2, 1.040, 0.505
#      81:    81, 345.000,        1, 0.997, 0.490
#      82:    82, 138.000,        1, 0.989, 0.475
#      83:    83, 138.000,        1, 0.985, 0.496
#      84:    84, 138.000,        1, 0.980, 0.540
#      85:    85, 138.000,        2, 0.985, 0.567
#      86:    86, 138.000,        1, 0.987, 0.543
#      87:    87, 161.000,        2, 1.015, 0.548
#      88:    88, 138.000,        1, 0.987, 0.622
#      89:    89, 138.000,        2, 1.005, 0.693
#      90:    90, 138.000,        2, 0.985, 0.581
#      91:    91, 138.000,        2, 0.980, 0.581
#      92:    92, 138.000,        2, 0.993, 0.590
#      93:    93, 138.000,        1, 0.987, 0.537
#      94:    94, 138.000,        1, 0.991, 0.500
#      95:    95, 138.000,        1, 0.981, 0.483
#      96:    96, 138.000,        1, 0.993, 0.480
#      97:    97, 138.000,        1, 1.011, 0.487
#      98:    98, 138.000,        1, 1.024, 0.478
#      99:    99, 138.000,        2, 1.010, 0.472
#     100:   100, 138.000,        2, 1.017, 0.489
#     101:   101, 138.000,        1, 0.993, 0.517
#     102:   102, 138.000,        1, 0.991, 0.564
#     103:   103, 138.000,        2, 1.001, 0.427
#     104:   104, 138.000,        2, 0.971, 0.379
#     105:   105, 138.000,        2, 0.965, 0.359
#     106:   106, 138.000,        1, 0.962, 0.355
#     107:   107, 138.000,        2, 0.952, 0.306
#     108:   108, 138.000,        1, 0.967, 0.338
#     109:   109, 138.000,        1, 0.967, 0.330
#     110:   110, 138.000,        2, 0.973, 0.316
#     111:   111, 138.000,        2, 0.980, 0.345
#     112:   112, 138.000,        2, 0.975, 0.262
#     113:   113, 138.000,        2, 0.993, 0.240
#     114:   114, 138.000,        1, 0.960, 0.252
#     115:   115, 138.000,        1, 0.960, 0.252
#     116:   116, 138.000,        2, 1.005, 0.473
#     117:   117, 138.000,        1, 0.974, 0.186
#     118:   118, 138.000,        1, 0.949, 0.383
#
#   default values:
#     vmin: 0.940
#     vmax: 1.060
#     area: 1
#     source_id: [(2)]
#     zone: 1
#
#
# Table: load
#          load_bus,    pd,    qd
#       1:        1, 0.510, 0.270
#       2:        2, 0.200, 0.090
#       3:        3, 0.390, 0.100
#       4:        4, 0.390, 0.120
#       5:        6, 0.520, 0.220
#       6:        7, 0.190, 0.020
#       7:        8, 0.280, 0.000
#       8:       11, 0.700, 0.230
#       9:       12, 0.470, 0.100
#      10:       13, 0.340, 0.160
#      11:       14, 0.140, 0.010
#      12:       15, 0.900, 0.300
#      13:       16, 0.250, 0.100
#      14:       17, 0.110, 0.030
#      15:       18, 0.600, 0.340
#      16:       19, 0.450, 0.250
#      17:       20, 0.180, 0.030
#      18:       21, 0.140, 0.080
#      19:       22, 0.100, 0.050
#      20:       23, 0.070, 0.030
#      21:       24, 0.130, 0.000
#      22:       27, 0.710, 0.130
#      23:       28, 0.170, 0.070
#      24:       29, 0.240, 0.040
#      25:       31, 0.430, 0.270
#      26:       32, 0.590, 0.230
#      27:       33, 0.230, 0.090
#      28:       34, 0.590, 0.260
#      29:       35, 0.330, 0.090
#      30:       36, 0.310, 0.170
#      31:       39, 0.270, 0.110
#      32:       40, 0.660, 0.230
#      33:       41, 0.370, 0.100
#      34:       42, 0.960, 0.230
#      35:       43, 0.180, 0.070
#      36:       44, 0.160, 0.080
#      37:       45, 0.530, 0.220
#      38:       46, 0.280, 0.100
#      39:       47, 0.340, 0.000
#      40:       48, 0.200, 0.110
#      41:       49, 0.870, 0.300
#      42:       50, 0.170, 0.040
#      43:       51, 0.170, 0.080
#      44:       52, 0.180, 0.050
#      45:       53, 0.230, 0.110
#      46:       54, 1.130, 0.320
#      47:       55, 0.630, 0.220
#      48:       56, 0.840, 0.180
#      49:       57, 0.120, 0.030
#      50:       58, 0.120, 0.030
#      51:       59, 2.770, 1.130
#      52:       60, 0.780, 0.030
#      53:       62, 0.770, 0.140
#      54:       66, 0.390, 0.180
#      55:       67, 0.280, 0.070
#      56:       70, 0.660, 0.200
#      57:       72, 0.120, 0.000
#      58:       73, 0.060, 0.000
#      59:       74, 0.680, 0.270
#      60:       75, 0.470, 0.110
#      61:       76, 0.680, 0.360
#      62:       77, 0.610, 0.280
#      63:       78, 0.710, 0.260
#      64:       79, 0.390, 0.320
#      65:       80, 1.300, 0.260
#      66:       82, 0.540, 0.270
#      67:       83, 0.200, 0.100
#      68:       84, 0.110, 0.070
#      69:       85, 0.240, 0.150
#      70:       86, 0.210, 0.100
#      71:       88, 0.480, 0.100
#      72:       90, 1.630, 0.420
#      73:       91, 0.100, 0.000
#      74:       92, 0.650, 0.100
#      75:       93, 0.120, 0.070
#      76:       94, 0.300, 0.160
#      77:       95, 0.420, 0.310
#      78:       96, 0.380, 0.150
#      79:       97, 0.150, 0.090
#      80:       98, 0.340, 0.080
#      81:       99, 0.420, 0.000
#      82:      100, 0.370, 0.180
#      83:      101, 0.220, 0.150
#      84:      102, 0.050, 0.030
#      85:      103, 0.230, 0.160
#      86:      104, 0.380, 0.250
#      87:      105, 0.310, 0.260
#      88:      106, 0.430, 0.160
#      89:      107, 0.500, 0.120
#      90:      108, 0.020, 0.010
#      91:      109, 0.080, 0.030
#      92:      110, 0.390, 0.300
#      93:      112, 0.680, 0.130
#      94:      113, 0.060, 0.000
#      95:      114, 0.080, 0.030
#      96:      115, 0.220, 0.070
#      97:      116, 1.840, 0.000
#      98:      117, 0.200, 0.080
#      99:      118, 0.330, 0.150
#
#   default values:
#     status: 1
#     source_id: [(2)]
#
#
# Table: shunt
#          shunt_bus,     bs
#       1:         5, -0.400
#       2:        34,  0.140
#       3:        37, -0.250
#       4:        44,  0.100
#       5:        45,  0.100
#       6:        46,  0.100
#       7:        48,  0.150
#       8:        74,  0.120
#       9:        79,  0.200
#      10:        82,  0.200
#      11:        83,  0.100
#      12:       105,  0.200
#      13:       107,  0.060
#      14:       110,  0.060
#
#   default values:
#     gs: 0.000
#     status: 1
#     source_id: [(2)]
#
#
# Table: gen
#          gen_bus,    pg,    vg,  pmax,    qmin,   qmax
#       1:       1, 0.000, 0.955, 1.000,  -0.050,  0.150
#       2:       4, 0.000, 0.998, 1.000,  -3.000,  3.000
#       3:       6, 0.000, 0.990, 1.000,  -0.130,  0.500
#       4:       8, 0.000, 1.015, 1.000,  -3.000,  3.000
#       5:      10, 4.500, 1.050, 5.500,  -1.470,  2.000
#       6:      12, 0.850, 0.990, 1.850,  -0.350,  1.200
#       7:      15, 0.000, 0.970, 1.000,  -0.100,  0.300
#       8:      18, 0.000, 0.973, 1.000,  -0.160,  0.500
#       9:      19, 0.000, 0.962, 1.000,  -0.080,  0.240
#      10:      24, 0.000, 0.992, 1.000,  -3.000,  3.000
#      11:      25, 2.200, 1.050, 3.200,  -0.470,  1.400
#      12:      26, 3.140, 1.015, 4.140, -10.000, 10.000
#      13:      27, 0.000, 0.968, 1.000,  -3.000,  3.000
#      14:      31, 0.070, 0.967, 1.070,  -3.000,  3.000
#      15:      32, 0.000, 0.963, 1.000,  -0.140,  0.420
#      16:      34, 0.000, 0.984, 1.000,  -0.080,  0.240
#      17:      36, 0.000, 0.980, 1.000,  -0.080,  0.240
#      18:      40, 0.000, 0.970, 1.000,  -3.000,  3.000
#      19:      42, 0.000, 0.985, 1.000,  -3.000,  3.000
#      20:      46, 0.190, 1.005, 1.190,  -1.000,  1.000
#      21:      49, 2.040, 1.025, 3.040,  -0.850,  2.100
#      22:      54, 0.480, 0.955, 1.480,  -3.000,  3.000
#      23:      55, 0.000, 0.952, 1.000,  -0.080,  0.230
#      24:      56, 0.000, 0.954, 1.000,  -0.080,  0.150
#      25:      59, 1.550, 0.985, 2.550,  -0.600,  1.800
#      26:      61, 1.600, 0.995, 2.600,  -1.000,  3.000
#      27:      62, 0.000, 0.998, 1.000,  -0.200,  0.200
#      28:      65, 3.910, 1.005, 4.910,  -0.670,  2.000
#      29:      66, 3.920, 1.050, 4.920,  -0.670,  2.000
#      30:      69, 5.164, 1.035, 8.052,  -3.000,  3.000
#      31:      70, 0.000, 0.984, 1.000,  -0.100,  0.320
#      32:      72, 0.000, 0.980, 1.000,  -1.000,  1.000
#      33:      73, 0.000, 0.991, 1.000,  -1.000,  1.000
#      34:      74, 0.000, 0.958, 1.000,  -0.060,  0.090
#      35:      76, 0.000, 0.943, 1.000,  -0.080,  0.230
#      36:      77, 0.000, 1.006, 1.000,  -0.200,  0.700
#      37:      80, 4.770, 1.040, 5.770,  -1.650,  2.800
#      38:      85, 0.000, 0.985, 1.000,  -0.080,  0.230
#      39:      87, 0.040, 1.015, 1.040,  -1.000, 10.000
#      40:      89, 6.070, 1.005, 7.070,  -2.100,  3.000
#      41:      90, 0.000, 0.985, 1.000,  -3.000,  3.000
#      42:      91, 0.000, 0.980, 1.000,  -1.000,  1.000
#      43:      92, 0.000, 0.990, 1.000,  -0.030,  0.090
#      44:      99, 0.000, 1.010, 1.000,  -1.000,  1.000
#      45:     100, 2.520, 1.017, 3.520,  -0.500,  1.550
#      46:     103, 0.400, 1.010, 1.400,  -0.150,  0.400
#      47:     104, 0.000, 0.971, 1.000,  -0.080,  0.230
#      48:     105, 0.000, 0.965, 1.000,  -0.080,  0.230
#      49:     107, 0.000, 0.952, 1.000,  -2.000,  2.000
#      50:     110, 0.000, 0.973, 1.000,  -0.080,  0.230
#      51:     111, 0.360, 0.980, 1.360,  -1.000, 10.000
#      52:     112, 0.000, 0.975, 1.000,  -1.000, 10.000
#      53:     113, 0.000, 0.993, 1.000,  -1.000,  2.000
#      54:     116, 0.000, 1.005, 1.000, -10.000, 10.000
#
#   default values:
#     qg: 0.000
#     mbase: 100.000
#     pmin: 0.000
#     gen_status: 1
#     model: 2
#     ncost: 3
#     cost: [(3)]
#     startup: 0.000
#     shutdown: 0.000
#     apf: 0.000
#     pc1: 0.000
#     pc2: 0.000
#     qc1max: 0.000
#     qc1min: 0.000
#     qc2max: 0.000
#     qc2min: 0.000
#     ramp_10: 0.000
#     ramp_30: 0.000
#     ramp_agc: 0.000
#     ramp_q: 0.000
#     source_id: [(2)]
#
#
# Table: branch
#          f_bus, t_bus,  br_r,  br_x,  b_fr,  b_to,   tap, transformer
#       1:     1,     2, 0.030, 0.100, 0.013, 0.013, 1.000,       false
#       2:     1,     3, 0.013, 0.042, 0.005, 0.005, 1.000,       false
#       3:     4,     5, 0.002, 0.008, 0.001, 0.001, 1.000,       false
#       4:     3,     5, 0.024, 0.108, 0.014, 0.014, 1.000,       false
#       5:     5,     6, 0.012, 0.054, 0.007, 0.007, 1.000,       false
#       6:     6,     7, 0.005, 0.021, 0.003, 0.003, 1.000,       false
#       7:     8,     9, 0.002, 0.030, 0.581, 0.581, 1.000,       false
#       8:     8,     5, 0.000, 0.027, 0.000, 0.000, 0.985,        true
#       9:     9,    10, 0.003, 0.032, 0.615, 0.615, 1.000,       false
#      10:     4,    11, 0.021, 0.069, 0.009, 0.009, 1.000,       false
#      11:     5,    11, 0.020, 0.068, 0.009, 0.009, 1.000,       false
#      12:    11,    12, 0.006, 0.020, 0.003, 0.003, 1.000,       false
#      13:     2,    12, 0.019, 0.062, 0.008, 0.008, 1.000,       false
#      14:     3,    12, 0.048, 0.160, 0.020, 0.020, 1.000,       false
#      15:     7,    12, 0.009, 0.034, 0.004, 0.004, 1.000,       false
#      16:    11,    13, 0.022, 0.073, 0.009, 0.009, 1.000,       false
#      17:    12,    14, 0.022, 0.071, 0.009, 0.009, 1.000,       false
#      18:    13,    15, 0.074, 0.244, 0.031, 0.031, 1.000,       false
#      19:    14,    15, 0.060, 0.195, 0.025, 0.025, 1.000,       false
#      20:    12,    16, 0.021, 0.083, 0.011, 0.011, 1.000,       false
#      21:    15,    17, 0.013, 0.044, 0.022, 0.022, 1.000,       false
#      22:    16,    17, 0.045, 0.180, 0.023, 0.023, 1.000,       false
#      23:    17,    18, 0.012, 0.050, 0.006, 0.006, 1.000,       false
#      24:    18,    19, 0.011, 0.049, 0.006, 0.006, 1.000,       false
#      25:    19,    20, 0.025, 0.117, 0.015, 0.015, 1.000,       false
#      26:    15,    19, 0.012, 0.039, 0.005, 0.005, 1.000,       false
#      27:    20,    21, 0.018, 0.085, 0.011, 0.011, 1.000,       false
#      28:    21,    22, 0.021, 0.097, 0.012, 0.012, 1.000,       false
#      29:    22,    23, 0.034, 0.159, 0.020, 0.020, 1.000,       false
#      30:    23,    24, 0.014, 0.049, 0.025, 0.025, 1.000,       false
#      31:    23,    25, 0.016, 0.080, 0.043, 0.043, 1.000,       false
#      32:    26,    25, 0.000, 0.038, 0.000, 0.000, 0.960,        true
#      33:    25,    27, 0.032, 0.163, 0.088, 0.088, 1.000,       false
#      34:    27,    28, 0.019, 0.086, 0.011, 0.011, 1.000,       false
#      35:    28,    29, 0.024, 0.094, 0.012, 0.012, 1.000,       false
#      36:    30,    17, 0.000, 0.039, 0.000, 0.000, 0.960,        true
#      37:     8,    30, 0.004, 0.050, 0.257, 0.257, 1.000,       false
#      38:    26,    30, 0.008, 0.086, 0.454, 0.454, 1.000,       false
#      39:    17,    31, 0.047, 0.156, 0.020, 0.020, 1.000,       false
#      40:    29,    31, 0.011, 0.033, 0.004, 0.004, 1.000,       false
#      41:    23,    32, 0.032, 0.115, 0.059, 0.059, 1.000,       false
#      42:    31,    32, 0.030, 0.098, 0.013, 0.013, 1.000,       false
#      43:    27,    32, 0.023, 0.076, 0.010, 0.010, 1.000,       false
#      44:    15,    33, 0.038, 0.124, 0.016, 0.016, 1.000,       false
#      45:    19,    34, 0.075, 0.247, 0.032, 0.032, 1.000,       false
#      46:    35,    36, 0.002, 0.010, 0.001, 0.001, 1.000,       false
#      47:    35,    37, 0.011, 0.050, 0.007, 0.007, 1.000,       false
#      48:    33,    37, 0.042, 0.142, 0.018, 0.018, 1.000,       false
#      49:    34,    36, 0.009, 0.027, 0.003, 0.003, 1.000,       false
#      50:    34,    37, 0.003, 0.009, 0.005, 0.005, 1.000,       false
#      51:    38,    37, 0.000, 0.038, 0.000, 0.000, 0.935,        true
#      52:    37,    39, 0.032, 0.106, 0.014, 0.014, 1.000,       false
#      53:    37,    40, 0.059, 0.168, 0.021, 0.021, 1.000,       false
#      54:    30,    38, 0.005, 0.054, 0.211, 0.211, 1.000,       false
#      55:    39,    40, 0.018, 0.060, 0.008, 0.008, 1.000,       false
#      56:    40,    41, 0.014, 0.049, 0.006, 0.006, 1.000,       false
#      57:    40,    42, 0.056, 0.183, 0.023, 0.023, 1.000,       false
#      58:    41,    42, 0.041, 0.135, 0.017, 0.017, 1.000,       false
#      59:    43,    44, 0.061, 0.245, 0.030, 0.030, 1.000,       false
#      60:    34,    43, 0.041, 0.168, 0.021, 0.021, 1.000,       false
#      61:    44,    45, 0.022, 0.090, 0.011, 0.011, 1.000,       false
#      62:    45,    46, 0.040, 0.136, 0.017, 0.017, 1.000,       false
#      63:    46,    47, 0.038, 0.127, 0.016, 0.016, 1.000,       false
#      64:    46,    48, 0.060, 0.189, 0.024, 0.024, 1.000,       false
#      65:    47,    49, 0.019, 0.062, 0.008, 0.008, 1.000,       false
#      66:    42,    49, 0.072, 0.323, 0.043, 0.043, 1.000,       false
#      67:    42,    49, 0.072, 0.323, 0.043, 0.043, 1.000,       false
#      68:    45,    49, 0.068, 0.186, 0.022, 0.022, 1.000,       false
#      69:    48,    49, 0.018, 0.050, 0.006, 0.006, 1.000,       false
#      70:    49,    50, 0.027, 0.075, 0.009, 0.009, 1.000,       false
#      71:    49,    51, 0.049, 0.137, 0.017, 0.017, 1.000,       false
#      72:    51,    52, 0.020, 0.059, 0.007, 0.007, 1.000,       false
#      73:    52,    53, 0.040, 0.164, 0.020, 0.020, 1.000,       false
#      74:    53,    54, 0.026, 0.122, 0.016, 0.016, 1.000,       false
#      75:    49,    54, 0.073, 0.289, 0.037, 0.037, 1.000,       false
#      76:    49,    54, 0.087, 0.291, 0.036, 0.036, 1.000,       false
#      77:    54,    55, 0.017, 0.071, 0.010, 0.010, 1.000,       false
#      78:    54,    56, 0.003, 0.010, 0.004, 0.004, 1.000,       false
#      79:    55,    56, 0.005, 0.015, 0.002, 0.002, 1.000,       false
#      80:    56,    57, 0.034, 0.097, 0.012, 0.012, 1.000,       false
#      81:    50,    57, 0.047, 0.134, 0.017, 0.017, 1.000,       false
#      82:    56,    58, 0.034, 0.097, 0.012, 0.012, 1.000,       false
#      83:    51,    58, 0.026, 0.072, 0.009, 0.009, 1.000,       false
#      84:    54,    59, 0.050, 0.229, 0.030, 0.030, 1.000,       false
#      85:    56,    59, 0.082, 0.251, 0.028, 0.028, 1.000,       false
#      86:    56,    59, 0.080, 0.239, 0.027, 0.027, 1.000,       false
#      87:    55,    59, 0.047, 0.216, 0.028, 0.028, 1.000,       false
#      88:    59,    60, 0.032, 0.145, 0.019, 0.019, 1.000,       false
#      89:    59,    61, 0.033, 0.150, 0.019, 0.019, 1.000,       false
#      90:    60,    61, 0.003, 0.014, 0.007, 0.007, 1.000,       false
#      91:    60,    62, 0.012, 0.056, 0.007, 0.007, 1.000,       false
#      92:    61,    62, 0.008, 0.038, 0.005, 0.005, 1.000,       false
#      93:    63,    59, 0.000, 0.039, 0.000, 0.000, 0.960,        true
#      94:    63,    64, 0.002, 0.020, 0.108, 0.108, 1.000,       false
#      95:    64,    61, 0.000, 0.027, 0.000, 0.000, 0.985,        true
#      96:    38,    65, 0.009, 0.099, 0.523, 0.523, 1.000,       false
#      97:    64,    65, 0.003, 0.030, 0.190, 0.190, 1.000,       false
#      98:    49,    66, 0.018, 0.092, 0.012, 0.012, 1.000,       false
#      99:    49,    66, 0.018, 0.092, 0.012, 0.012, 1.000,       false
#     100:    62,    66, 0.048, 0.218, 0.029, 0.029, 1.000,       false
#     101:    62,    67, 0.026, 0.117, 0.016, 0.016, 1.000,       false
#     102:    65,    66, 0.000, 0.037, 0.000, 0.000, 0.935,        true
#     103:    66,    67, 0.022, 0.102, 0.013, 0.013, 1.000,       false
#     104:    65,    68, 0.001, 0.016, 0.319, 0.319, 1.000,       false
#     105:    47,    69, 0.084, 0.278, 0.035, 0.035, 1.000,       false
#     106:    49,    69, 0.098, 0.324, 0.041, 0.041, 1.000,       false
#     107:    68,    69, 0.000, 0.037, 0.000, 0.000, 0.935,        true
#     108:    69,    70, 0.030, 0.127, 0.061, 0.061, 1.000,       false
#     109:    24,    70, 0.002, 0.412, 0.051, 0.051, 1.000,       false
#     110:    70,    71, 0.009, 0.036, 0.004, 0.004, 1.000,       false
#     111:    24,    72, 0.049, 0.196, 0.024, 0.024, 1.000,       false
#     112:    71,    72, 0.045, 0.180, 0.022, 0.022, 1.000,       false
#     113:    71,    73, 0.009, 0.045, 0.006, 0.006, 1.000,       false
#     114:    70,    74, 0.040, 0.132, 0.017, 0.017, 1.000,       false
#     115:    70,    75, 0.043, 0.141, 0.018, 0.018, 1.000,       false
#     116:    69,    75, 0.040, 0.122, 0.062, 0.062, 1.000,       false
#     117:    74,    75, 0.012, 0.041, 0.005, 0.005, 1.000,       false
#     118:    76,    77, 0.044, 0.148, 0.018, 0.018, 1.000,       false
#     119:    69,    77, 0.031, 0.101, 0.052, 0.052, 1.000,       false
#     120:    75,    77, 0.060, 0.200, 0.025, 0.025, 1.000,       false
#     121:    77,    78, 0.004, 0.012, 0.006, 0.006, 1.000,       false
#     122:    78,    79, 0.005, 0.024, 0.003, 0.003, 1.000,       false
#     123:    77,    80, 0.017, 0.048, 0.024, 0.024, 1.000,       false
#     124:    77,    80, 0.029, 0.105, 0.011, 0.011, 1.000,       false
#     125:    79,    80, 0.016, 0.070, 0.009, 0.009, 1.000,       false
#     126:    68,    81, 0.002, 0.020, 0.404, 0.404, 1.000,       false
#     127:    81,    80, 0.000, 0.037, 0.000, 0.000, 0.935,        true
#     128:    77,    82, 0.030, 0.085, 0.041, 0.041, 1.000,       false
#     129:    82,    83, 0.011, 0.037, 0.019, 0.019, 1.000,       false
#     130:    83,    84, 0.062, 0.132, 0.013, 0.013, 1.000,       false
#     131:    83,    85, 0.043, 0.148, 0.017, 0.017, 1.000,       false
#     132:    84,    85, 0.030, 0.064, 0.006, 0.006, 1.000,       false
#     133:    85,    86, 0.035, 0.123, 0.014, 0.014, 1.000,       false
#     134:    86,    87, 0.028, 0.207, 0.022, 0.022, 1.000,       false
#     135:    85,    88, 0.020, 0.102, 0.014, 0.014, 1.000,       false
#     136:    85,    89, 0.024, 0.173, 0.024, 0.024, 1.000,       false
#     137:    88,    89, 0.014, 0.071, 0.010, 0.010, 1.000,       false
#     138:    89,    90, 0.052, 0.188, 0.026, 0.026, 1.000,       false
#     139:    89,    90, 0.024, 0.100, 0.053, 0.053, 1.000,       false
#     140:    90,    91, 0.025, 0.084, 0.011, 0.011, 1.000,       false
#     141:    89,    92, 0.010, 0.050, 0.027, 0.027, 1.000,       false
#     142:    89,    92, 0.039, 0.158, 0.021, 0.021, 1.000,       false
#     183:    68,   116, 0.000, 0.004, 0.082, 0.082, 1.000,       false
#     184:    12,   117, 0.033, 0.140, 0.018, 0.018, 1.000,       false
#     185:    75,   118, 0.014, 0.048, 0.006, 0.006, 1.000,       false
#     186:    76,   118, 0.016, 0.054, 0.007, 0.007, 1.000,       false
#
#   default values:
#     g_fr: 0.000
#     g_to: 0.000
#     shift: 0.000
#     rate_a: 99.000
#     br_status: 1
#     angmax: 1.047
#     angmin: -1.047
#     source_id: [(2)]

# %%
# Assign a new value(solution value of basic DCOPF model) to the power generation
network_base_con_dc = deepcopy(case_data)
result_dc = run_opf(network_base_con_dc,DCPPowerModel, solver)
PowerModels.update_data!(network_base_con_dc,result_dc) 
network_base_con_dc_vio = deepcopy(network_base_con_dc)
gen_number = length(network_base_con_dc_vio["gen"])
for i in 1:gen_number
    network_base_con_dc_vio["gen"][string(i)]["pg"] = network_base_con_dc_vio["solution"]["gen"][string(i)]["pg"]
    network_base_con_dc_vio["gen"][string(i)]["qg"] = 0
end

# deletes unwanted parameters from the data
delete!(network_base_con_dc_vio,"optimizer")
delete!(network_base_con_dc_vio,"objective")
delete!(network_base_con_dc_vio,"data")
delete!(network_base_con_dc_vio,"objective_lb")
delete!(network_base_con_dc_vio,"solution")
delete!(network_base_con_dc_vio,"termination_status")
delete!(network_base_con_dc_vio,"machine")
delete!(network_base_con_dc_vio,"dual_status")
delete!(network_base_con_dc_vio,"primal_status")
delete!(network_base_con_dc_vio,"solve_time")
# Out:
# [warn | InfrastructureModels]: running update_data with data that does not include per_unit field, units may be incorrect
# Dict{String,Any} with 13 entries:
#   "bus"            => Dict{String,Any}("32"=>Dict{String,Any}("zone"=>1,"bus_i"…
#   "source_type"    => "matpower"
#   "name"           => "case118"
#   "dcline"         => Dict{String,Any}()
#   "source_version" => "2"
#   "gen"            => Dict{String,Any}("32"=>Dict{String,Any}("pmin"=>0.0,"qc1m…
#   "branch"         => Dict{String,Any}("1"=>Dict{String,Any}("br_r"=>0.0303,"ra…
#   "storage"        => Dict{String,Any}()
#   "switch"         => Dict{String,Any}()
#   "baseMVA"        => 100
#   "per_unit"       => true
#   "shunt"          => Dict{String,Any}("4"=>Dict{String,Any}("source_id"=>Any["…
#   "load"           => Dict{String,Any}("32"=>Dict{String,Any}("source_id"=>Any[…

# %%
network_base_con_dc_vio["gen"]
# Out:
# Dict{String,Any} with 54 entries:
#   "32" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "29" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>3.79875,"model"=>2,"…
#   "1"  => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "54" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "2"  => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "41" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "51" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.348864,"model"=>2,…
#   "53" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "27" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "42" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "33" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "28" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>3.78906,"model"=>2,"…
#   "50" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "52" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "26" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>1.55051,"model"=>2,"…
#   "10" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "24" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "25" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>1.50206,"model"=>2,"…
#   "23" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "49" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "5"  => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>4.36081,"model"=>2,"…
#   "31" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "43" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   "39" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0387627,"model"=>2…
#   "34" => Dict{String,Any}("pmin"=>0.0,"qc1max"=>0.0,"pg"=>0.0,"model"=>2,"shut…
#   ⋮    => ⋮

# %%
# this function is to compute the scopf problem with one specific branch contingency
# the input is the dataset of the whole network and the contingency
# the output is solution of the problem if it has feasible, if it is not feasible the model will return "infeasible"
function run_dc_scopf_contingency(network,contingency::Int64)
    
    bus_number = length(network["bus"])
    gen_number = length(network["gen"])
    branch_number = length(network["branch"])
    # variable
    model_dc_scopf = Model(with_optimizer(Ipopt.Optimizer, tol=1e-9, print_level=0))
    @variable(model_dc_scopf, flow[1:branch_number])
    @variable(model_dc_scopf,voltage_phase[1:bus_number]) 
    @variable(model_dc_scopf, bus_p[1:bus_number],lower_bound=0)
    @variable(model_dc_scopf, gen_p[1:gen_number])
    @variable(model_dc_scopf, gen_cost[1:gen_number])



        
    beta_g = []
    for i in 1:gen_number
        gen_index = string(i)
        push!(beta_g,network["gen"][gen_index]["gen_bus"])
    end  

        bus_p0 = zeros(1,bus_number)
        for i in 1:gen_number
            gen_index = string(i)
            bus_name = network["gen"][gen_index]["gen_bus"]
            bus_produce = network["gen"][gen_index]["pg"]
            bus_p0[bus_name] = bus_produce
        end

    bus_d = zeros(1,bus_number)
    for i in 1:length(network["load"])
        load_index = string(i)
        bus_name = network["load"][load_index]["load_bus"]
        bus_demand = network["load"][load_index]["pd"]
        bus_d[bus_name] = bus_demand
    end

    ab_l = []
    for i in 1:branch_number
        abl = []
        branch_index = string(i)
        push!(abl,network["branch"][branch_index]["f_bus"])
        push!(abl,network["branch"][branch_index]["t_bus"])
        push!(ab_l,abl)
    end

    A_bl=zeros(bus_number,branch_number)
    from_bus = 0
    to_bus = 0
    for i in 1:branch_number
        from_bus = ab_l[i][1]
        to_bus = ab_l[i][2]
        A_bl[(i-1)*bus_number+from_bus] = -1
        A_bl[(i-1)*bus_number+to_bus] = 1
    end 

    flow_bus_matrix = A_bl*flow

    line_matrix = A_bl'*voltage_phase
    V0 = 1

    bus_p_max = zeros(1,bus_number)
    for i in 1:gen_number
        gen_index = string(i)
        bus_name = network["gen"][gen_index]["gen_bus"]
        bus_produce_max = network["gen"][gen_index]["pmax"]
        bus_p_max[bus_name] = bus_produce_max
    end
    
        bus_p_min = zeros(1,bus_number)
        for i in 1:gen_number
            gen_index = string(i)
            bus_name = network["gen"][gen_index]["gen_bus"]
            bus_produce_min = network["gen"][gen_index]["pmin"]
            bus_p_min[bus_name] = bus_produce_min
        end

    
   for i in 1:gen_number
       gen_index = string(i)
       bus_index = network["gen"][gen_index]["gen_bus"]
       @constraint(model_dc_scopf,gen_p[i] == bus_p[bus_index])
   end

    # value of objective function
    gen_cost_con=[]
    for i in 1:gen_number
        gen_index = string(i)
        push!(gen_cost_con,@constraint(model_dc_scopf,gen_cost[i] == network["gen"][gen_index]["cost"][1]*gen_p[i]^2+network["gen"][gen_index]["cost"][2]*gen_p[i]+network["gen"][gen_index]["cost"][3]))
    end    
    
    F_max = []
    for i in 1:branch_number
        branch_index = string(i)
        push!(F_max,network["branch"][branch_index]["rate_a"])
    end  

    # generation limit
    for i in 1:bus_number
        if i in beta_g
            @constraint(model_dc_scopf, bus_p[i] >= bus_p_min[i])
            @constraint(model_dc_scopf, bus_p[i] <= bus_p_max[i])
        else
            @constraint(model_dc_scopf, bus_p[i] == 0)
        end
    end

    # thermal limit
    for i in 1:branch_number
        @constraint(model_dc_scopf, flow[i] - F_max[i]<=0)
        @constraint(model_dc_scopf, -flow[i]- F_max[i]<=0)
    end 

    # Kirchhoff current law
    con1= []
    for i in 1:bus_number
        bus_index = string(i)
        push!(con1,@constraint(model_dc_scopf, flow_bus_matrix[i]- bus_d[i]== -bus_p[i] ))
    end

    #contingency : the power flow in contingency branch is zero
    @constraint(model_dc_scopf, flow[contingency] == 0)
    
    # Kirchhoff voltage law(without contingency branch)
    con2 = []
    for i in 1:branch_number
        if i==contingency
        else
            branch_index = string(i)
            push!(con2, @constraint(model_dc_scopf, (-V0^2/network["branch"][branch_index]["br_x"])*line_matrix[i] == flow[i]))
        end
    end
    
    # Setting the Reference Bus (Bus 1) angles to 0
    @constraint(model_dc_scopf, voltage_phase[1] == 0)


    # objective
    @objective(model_dc_scopf, Min,sum(gen_cost))
    
    #set_optimizer(model_dc_scopf, Ipopt.Optimizer,print_level=0)
    optimize!(model_dc_scopf) 
    
    status = termination_status(model_dc_scopf)
    if contingency == 134
        return("infeasible")
    else
        if status == LOCALLY_SOLVED
            return(value.(sum(gen_cost)))
        else contingency
            return("infeasible")
        end
    end
    
    
end
# Out:
# run_dc_scopf_contingency (generic function with 1 method)

# %%
infeasible_contingency = []
for i in 1:length(case_data["branch"])
    if run_dc_scopf_contingency(case_data,i)=="infeasible"
        push!(infeasible_contingency,i)
    end
end

# %%
infeasible_contingency
# Out:
# 3-element Array{Any,1}:
#  134
#  183
#  184

# %%
# this function is to compute the scopf problem with all feasible branch contingency
# the input is the dataset of the whole network 
# the output is solution of the problem if it has feasible, if it is not feasible the model will return "infeasible"
# this function is very similar to "run_dc_scopf_contingency"
function run_dc_scopf(network)
    
    bus_number = length(network["bus"])
    gen_number = length(network["gen"])
    branch_number = length(network["branch"])
    contingency_number = length(network["branch"])

    model_dc_scopf = Model(with_optimizer(Ipopt.Optimizer))
    @variable(model_dc_scopf, flow[1:contingency_number,1:branch_number])
    @variable(model_dc_scopf,voltage_phase[1:contingency_number,1:bus_number]) 
    @variable(model_dc_scopf, bus_p[1:bus_number],lower_bound=0)
    @variable(model_dc_scopf, gen_p[1:gen_number])
    @variable(model_dc_scopf, gen_cost[1:gen_number])
    
    
    beta_g = []
    for i in 1:gen_number
        gen_index = string(i)
        push!(beta_g,network["gen"][gen_index]["gen_bus"])
    end  

    bus_p0 = zeros(1,bus_number)
    for i in 1:gen_number
        gen_index = string(i)
        bus_name = network["gen"][gen_index]["gen_bus"]
        bus_produce = network["gen"][gen_index]["pg"]
        bus_p0[bus_name] = bus_produce
    end

    bus_d = zeros(1,bus_number)
    for i in 1:length(network["load"])
        load_index = string(i)
        bus_name = network["load"][load_index]["load_bus"]
        bus_demand = network["load"][load_index]["pd"]
        bus_d[bus_name] = bus_demand
    end

    ab_l = []
    for i in 1:branch_number
        abl = []
        branch_index = string(i)
        push!(abl,network["branch"][branch_index]["f_bus"])
        push!(abl,network["branch"][branch_index]["t_bus"])
        push!(ab_l,abl)
    end

    A_bl=zeros(bus_number,branch_number)
    from_bus = 0
    to_bus = 0
    for i in 1:branch_number
        from_bus = ab_l[i][1]
        to_bus = ab_l[i][2]
        A_bl[(i-1)*bus_number+from_bus] = -1
        A_bl[(i-1)*bus_number+to_bus] = 1
    end 

    V0 = 1

    bus_p_max = zeros(1,bus_number)
    for i in 1:gen_number
        gen_index = string(i)
        bus_name = network["gen"][gen_index]["gen_bus"]
        bus_produce_max = network["gen"][gen_index]["pmax"]
        bus_p_max[bus_name] = bus_produce_max
    end
    
    bus_p_min = zeros(1,bus_number)
    for i in 1:gen_number
        gen_index = string(i)
        bus_name = network["gen"][gen_index]["gen_bus"]
        bus_produce_min = network["gen"][gen_index]["pmin"]
        bus_p_min[bus_name] = bus_produce_min
    end
    
        
    F_max = []
    for i in 1:branch_number
        branch_index = string(i)
        push!(F_max,network["branch"][branch_index]["rate_a"])
    end  
    
    for i in 1:gen_number
        gen_index = string(i)
        bus_index = network["gen"][gen_index]["gen_bus"]
        @constraint(model_dc_scopf,gen_p[i] == bus_p[bus_index])
    end

    gen_cost_con=[]
    for i in 1:gen_number
        gen_index = string(i)
        push!(gen_cost_con,@constraint(model_dc_scopf,gen_cost[i] == network["gen"][gen_index]["cost"][1]*gen_p[i]^2+network["gen"][gen_index]["cost"][2]*gen_p[i]+network["gen"][gen_index]["cost"][3]))
    end    


    for i in 1:bus_number
        if i in beta_g
            @constraint(model_dc_scopf, bus_p[i] >= bus_p_min[i])
            @constraint(model_dc_scopf, bus_p[i] <= bus_p_max[i])
        else
            @constraint(model_dc_scopf, bus_p[i] == 0)
        end
    end
    
    # consraints under all contingency 
    for i in 1:contingency_number
        
        for j in 1:branch_number
            @constraint(model_dc_scopf, flow[i,j] - F_max[j]<=0)
            @constraint(model_dc_scopf, -flow[i,j]- F_max[j]<=0)
        end

        for j in 1:bus_number
            f_m = A_bl*flow[i,:]
            @constraint(model_dc_scopf, f_m[j] - bus_d[j]== -bus_p[j] )
        end
        
        l_m = A_bl'*voltage_phase[i,:]
        
        if i in infeasible_contingency
            for j in 1:branch_number
                branch_index = string(i)
                @constraint(model_dc_scopf, (-V0^2/network["branch"][branch_index]["br_x"])*l_m[j] == flow[i,j])
            end           
        else   
            for j in 1:branch_number
                if j==i
                # the power flow in contingency branch is zero
                    @constraint(model_dc_scopf, flow[i,j] == 0)
                else
                    branch_index = string(i)
                    @constraint(model_dc_scopf, (-V0^2/network["branch"][branch_index]["br_x"])*l_m[j] == flow[i,j])
                end
            end
        end
    
    end    

    # objective
    @objective(model_dc_scopf, Min,sum(gen_cost))
    
    optimize!(model_dc_scopf) 
    
    status = termination_status(model_dc_scopf)
    if status == LOCALLY_SOLVED
        return(value.(gen_p))
    else
        return("infeasible")
    end
    
end
# Out:
# run_dc_scopf (generic function with 2 methods)

# %%
# run the case30, there is no feasible solution under all branch contingency
run_dc_scopf(case_data)
# Out:
# ┌ Warning: `with_optimizer` is deprecated. Adapt the following example to update your code:
# │ `with_optimizer(Ipopt.Optimizer)` becomes `Ipopt.Optimizer`.
# │   caller = run_dc_scopf(::Dict{String,Any}) at In[124]:12
# └ @ Main .\In[124]:12
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:
-09
#
#
# Number of objective function evaluations             = 21
# Number of objective gradient evaluations             = 21
# Number of equality constraint evaluations            = 21
# Number of inequality constraint evaluations          = 21
# Number of equality constraint Jacobian evaluations   = 21
# Number of inequality constraint Jacobian evaluations = 21
# Number of Lagrangian Hessian evaluations             = 20
# Total CPU secs in IPOPT (w/o function evaluations)   =     28.245
# Total CPU secs in NLP function evaluations           =      0.140
#
# EXIT: Optimal Solution Found.
# 54-element Array{Float64,1}:
#   0.07037621436323055
#   0.0703762143465878
#   0.07037621435140667
#   0.07037621426676151
#  -9.9999672365568e-9
#   0.8559824061215215
#   0.07037621430294988
#   0.07037621428658986
#   0.07037621428329206
#   0.07037621412764268
#   2.2154849823812874
#   3.1621014826979814
#   0.07037621420348028
#   ⋮
#   0.07037621392346029
#   0.07037621397602023
#   2.537737343441578
#   0.40281504853391015
#   0.07037621397690784
#   0.07037621398766829
#   0.07037621399734394
#   0.0703762139922614
#  -9.999967095093252e-9
#   0.6799999999989285
#   0.07037621424331161
#   0.0703762141439599

# %%
# this function is to find all the violation branch under all contingency
# the input is the dataset of the whole network
# the output is the number of violation contingencies, the index of these branches, their violation value and the corresopnding lagrange multiplier
# this can be used to compute all the sub problems for a grid
function benders_subproblem_test(network)
    contingency_violation = []
    lagrangian_multiplier_set = []
    violate_branch = []
    
    # scan all contingency 
    for contingency in 1:length(network["branch"])
    
        bus_number = length(network["bus"])
        gen_number = length(network["gen"])
        branch_number = length(network["branch"])
        # model name
        model_dc_slack = Model()
        # model variables
        # slack variables
        @variable(model_dc_slack, slack1[1:branch_number],lower_bound=0)
        @variable(model_dc_slack, slack2[1:branch_number],lower_bound=0)
        @variable(model_dc_slack, slack3[1:bus_number],lower_bound=0)
        @variable(model_dc_slack, slack4[1:bus_number],lower_bound=0)
        @variable(model_dc_slack, flow[1:branch_number])
        @variable(model_dc_slack,voltage_phase[1:bus_number]) 

    
        # the parameters that needed in the model
        # max thermal limits for each line
        F_max = []
        for i in 1:branch_number
            branch_index = string(i)
            push!(F_max,network_con["branch"][branch_index]["rate_a"])
        end  

        beta_g = []
        for i in 1:gen_number
            gen_index = string(i)
           push!(beta_g,network["gen"][gen_index]["gen_bus"])
        end  
        # given value of generation
        bus_p0 = zeros(1,bus_number)
        for i in 1:gen_number
            gen_index = string(i)
            bus_name = network["gen"][gen_index]["gen_bus"]
            bus_produce = network["gen"][gen_index]["pg"]
            bus_p0[bus_name] = bus_produce
        end
        # power demand for each bus
        bus_d = zeros(1,bus_number)
        for i in 1:length(network["load"])
            load_index = string(i)
            bus_name = network["load"][load_index]["load_bus"]
            bus_demand = network["load"][load_index]["pd"]
            bus_d[bus_name] = bus_demand
        end

        ab_l = []
        for i in 1:branch_number
            abl = []
            branch_index = string(i)
            push!(abl,network["branch"][branch_index]["f_bus"])
            push!(abl,network["branch"][branch_index]["t_bus"])
            push!(ab_l,abl)
        end

        A_bl=zeros(bus_number,branch_number)
        from_bus = 0
        to_bus = 0
        for i in 1:branch_number
            from_bus = ab_l[i][1]
            to_bus = ab_l[i][2]
            A_bl[(i-1)*bus_number+from_bus] = -1
            A_bl[(i-1)*bus_number+to_bus] = 1
        end 
        

        flow_bus_matrix = A_bl*flow

        V0 = 1
        line_matrix = A_bl'*voltage_phase
        
        # flow constrain
        flow_max_con = []
        flow_min_con = []
        for i in 1:branch_number
            push!(flow_max_con,@constraint(model_dc_slack, flow[i]-slack1[i] <= F_max[i]))
            push!(flow_min_con,@constraint(model_dc_slack, - F_max[i] <= flow[i] + slack2[i] ))
        end 
    
        #Kirchhoff current law
        power_balance = []
        for i in 1:bus_number
            bus_index = string(i)
            push!(power_balance,@constraint(model_dc_slack, flow_bus_matrix[i]- bus_d[i]+ slack3[i] - slack4[i]== -bus_p0[i] ))
        end

        # Setting the Reference Bus (Bus 1) angles to 0
        @constraint(model_dc_slack, voltage_phase[1] == 0)

        #contingency : the power flow in contingency branch is zero
        @constraint(model_dc_slack, flow[contingency] == 0)
        
        # Kirchhoff voltage law(without contingency branch)
        voltage_law = []
        for i in 1:(contingency-1)
            branch_index = string(i)
            push!(voltage_law, @constraint(model_dc_slack, (-V0^2/network_con["branch"][branch_index]["br_x"])*line_matrix[i] == flow[i]))
        end 
        for i in (contingency+1):branch_number
            branch_index = string(i)
            push!(voltage_law, @constraint(model_dc_slack, (-V0^2/network_con["branch"][branch_index]["br_x"])*line_matrix[i] == flow[i]))
        end 



        # objective function: minimize the all the violation value
        violation = @objective(model_dc_slack, Min, sum(sum(sum(slack1[i] for i in [1:branch_number])+ sum(slack2[j] for j in [1:branch_number]))+sum(sum(slack3[m] for m in [1:bus_number])+sum(slack4[n] for n in [1:bus_number]))))

        
        # set "Ipopt" as solver
        set_optimizer(model_dc_slack, Xpress.Optimizer)
        optimize!(model_dc_slack)
    

    #lagrangian_multiplier 
    lagrangian_multiplier =  -dual.(power_balance)

        # check violation value is larger than 0 or not
        if value.(violation)>10e-6
             push!(lagrangian_multiplier_set,lagrangian_multiplier)
             push!(violate_branch,contingency)
             push!(contingency_violation,value.(violation))
        end         
    end
    num = length(violate_branch)
    # final output
    return (num,violate_branch,lagrangian_multiplier_set,contingency_violation)

end
# Out:
# benders_subproblem_test (generic function with 1 method)

# %%
# this function is to find all the power flow violation branch for a specific contingency
# the input is the dataset of the whole network and a contingency
# the output is to tell whether the critical contingency is power flow violation contingency or not
# this can only be used to check one contingency for each time
# this function is almost the same with the above one
function benders_subproblem(network, contingency)
    contingency_violation = []
    lagrangian_multiplier_set = []
    violate_branch = []
    
    
    bus_number = length(network["bus"])
    gen_number = length(network["gen"])
    branch_number = length(network["branch"])
    
    model_dc_fpv = Model()
    @variable(model_dc_fpv, slack1[1:branch_number],lower_bound=0)
    @variable(model_dc_fpv, slack2[1:branch_number],lower_bound=0)
    @variable(model_dc_fpv, slack3[1:bus_number],lower_bound=0)
    @variable(model_dc_fpv, slack4[1:bus_number],lower_bound=0)
    @variable(model_dc_fpv, flow[1:branch_number])
    @variable(model_dc_fpv,voltage_phase[1:bus_number]) 

    
    #F_max = 2
    F_max = []
    for i in 1:branch_number
        branch_index = string(i)
        push!(F_max,network_con["branch"][branch_index]["rate_a"])
    end  

    beta_g = []
    for i in 1:gen_number
        gen_index = string(i)
        push!(beta_g,network["gen"][gen_index]["gen_bus"])
    end  

    bus_p0 = zeros(1,bus_number)
    for i in 1:gen_number
        gen_index = string(i)
        bus_name = network["gen"][gen_index]["gen_bus"]
        bus_produce = network["gen"][gen_index]["pg"]
        bus_p0[bus_name] = bus_produce
    end

    bus_d = zeros(1,bus_number)
    for i in 1:length(network["load"])
        load_index = string(i)
        bus_name = network["load"][load_index]["load_bus"]
        bus_demand = network["load"][load_index]["pd"]
        bus_d[bus_name] = bus_demand
    end

    ab_l = []
    for i in 1:branch_number
        abl = []
        branch_index = string(i)
        push!(abl,network["branch"][branch_index]["f_bus"])
        push!(abl,network["branch"][branch_index]["t_bus"])
        push!(ab_l,abl)
    end

    A_bl=zeros(bus_number,branch_number)
    from_bus = 0
    to_bus = 0
    for i in 1:branch_number
        from_bus = ab_l[i][1]
        to_bus = ab_l[i][2]
        A_bl[(i-1)*bus_number+from_bus] = -1
        A_bl[(i-1)*bus_number+to_bus] = 1
    end 
        

    flow_bus_matrix = A_bl*flow



    V0 = 1
    line_matrix = A_bl'*voltage_phase

    flow_max_con = []
    flow_min_con = []
    for i in 1:branch_number
        push!(flow_max_con,@constraint(model_dc_fpv, flow[i]-slack1[i] <= F_max[i]))
        push!(flow_min_con,@constraint(model_dc_fpv, - F_max[i] <= flow[i] + slack2[i] ))
    end 
    
    power_balance = []
    for i in 1:bus_number
        bus_index = string(i)
        push!(power_balance,@constraint(model_dc_fpv, flow_bus_matrix[i]- bus_d[i]+ slack3[i] - slack4[i]== -bus_p0[i] ))
    end

    # Setting the Reference Bus (Bus 1) angles to 0
    @constraint(model_dc_fpv, voltage_phase[1] == 0)

    # set contingency 
    @constraint(model_dc_fpv, flow[contingency] == 0)
    # Kirchhoff voltage law
    voltage_law = []
    for i in 1:(contingency-1)
        branch_index = string(i)
        push!(voltage_law, @constraint(model_dc_fpv, (-V0^2/network_con["branch"][branch_index]["br_x"])*line_matrix[i] == flow[i]))
    end 

    for i in (contingency+1):branch_number
        branch_index = string(i)
        push!(voltage_law, @constraint(model_dc_fpv, (-V0^2/network_con["branch"][branch_index]["br_x"])*line_matrix[i] == flow[i]))
    end 



    # objective
    violation = @objective(model_dc_fpv, Min, sum(sum(sum(slack1[i] for i in [1:branch_number])+ sum(slack2[j] for j in [1:branch_number]))+sum(sum(slack3[m] for m in [1:bus_number])+sum(slack4[n] for n in [1:bus_number]))))

    set_optimizer(model_dc_fpv, Xpress.Optimizer)
    optimize!(model_dc_fpv)
    

    #lagrangian_multiplier 
    lagrangian_multiplier =  -dual.(power_balance)

    # check violation value is larger than 0 or not
    if value.(violation)>10e-8
        return(contingency,lagrangian_multiplier,value.(violation))
    else
        return("not violation")
    end
end
# Out:
# benders_subproblem (generic function with 1 method)

# %%
# this function is add benders cut to the master problem for a specific contingency violation
# the input is the dataset of the whole network , a contingency, violation value ans lagrangian multiplier
# the output is solution of basic dcopf model with a benders cut
# this can only be used to one cut for each time
function run_dc_opf_with_benderscut(network,lagrangian_multiplier_set_list::Array,contingency_violation_list::Array,violate_branch_number::Int64)
    
    bus_number = length(network["bus"])
    gen_number = length(network["gen"])
    branch_number = length(network["branch"])

    model_dc_benders_cut = Model(with_optimizer(Ipopt.Optimizer))
    # model variable
    @variable(model_dc_benders_cut, flow[1:branch_number])
    @variable(model_dc_benders_cut,voltage_phase[1:bus_number]) 
    @variable(model_dc_benders_cut, bus_p[1:bus_number],lower_bound=0)
    @variable(model_dc_benders_cut, gen_p[1:gen_number])
    @variable(model_dc_benders_cut, gen_cost[1:gen_number])
    # this variable is used to generated benders cut 
    @variable(model_dc_benders_cut, bus_add_cut[1:bus_number])

    beta_g = []
    for i in 1:gen_number
        gen_index = string(i)
        push!(beta_g,network["gen"][gen_index]["gen_bus"])
    end  

    bus_p0 = zeros(1,bus_number)
    for i in 1:gen_number
        gen_index = string(i)
        bus_name = network["gen"][gen_index]["gen_bus"]
        bus_produce = network["gen"][gen_index]["pg"]
        bus_p0[bus_name] = bus_produce
    end

    bus_d = zeros(1,bus_number)
    for i in 1:length(network["load"])
        load_index = string(i)
        bus_name = network["load"][load_index]["load_bus"]
        bus_demand = network["load"][load_index]["pd"]
        bus_d[bus_name] = bus_demand
    end

    ab_l = []
    for i in 1:branch_number
        abl = []
        branch_index = string(i)
        push!(abl,network["branch"][branch_index]["f_bus"])
        push!(abl,network["branch"][branch_index]["t_bus"])
        push!(ab_l,abl)
    end

    A_bl=zeros(bus_number,branch_number)
    from_bus = 0
    to_bus = 0
    for i in 1:branch_number
        from_bus = ab_l[i][1]
        to_bus = ab_l[i][2]
        A_bl[(i-1)*bus_number+from_bus] = -1
        A_bl[(i-1)*bus_number+to_bus] = 1
    end 

    flow_bus_matrix = A_bl*flow

    line_matrix = A_bl'*voltage_phase
    V0 = 1

    bus_p_max = zeros(1,bus_number)
    for i in 1:gen_number
        gen_index = string(i)
        bus_name = network["gen"][gen_index]["gen_bus"]
        bus_produce_max = network["gen"][gen_index]["pmax"]
        bus_p_max[bus_name] = bus_produce_max
    end
    
        bus_p_min = zeros(1,bus_number)
        for i in 1:gen_number
            gen_index = string(i)
            bus_name = network["gen"][gen_index]["gen_bus"]
            bus_produce_min = network["gen"][gen_index]["pmin"]
            bus_p_min[bus_name] = bus_produce_min
        end

    #bender cut
    benders1 = []
    for i in 1:bus_number
        push!(benders1,@constraint(model_dc_benders_cut,(bus_p[i]-bus_p0[i])*lagrangian_multiplier_set_list[violate_branch_number][i] ==bus_add_cut[i]))
    end
    
     benders_cut_add = @constraint(model_dc_benders_cut, sum(bus_add_cut)+contingency_violation_list[violate_branch_number]<=0)

    # total generation cost
    for i in 1:gen_number
        gen_index = string(i)
        bus_index = network["gen"][gen_index]["gen_bus"]
        @constraint(model_dc_benders_cut,gen_p[i] == bus_p[bus_index])
    end

    gen_cost_con=[]
    for i in 1:gen_number
        gen_index = string(i)
        push!(gen_cost_con,@constraint(model_dc_benders_cut,gen_cost[i] == network["gen"][gen_index]["cost"][1]*gen_p[i]^2+network["gen"][gen_index]["cost"][2]*gen_p[i]+network["gen"][gen_index]["cost"][3]))
    end    
    

     F_max = []
     for i in 1:branch_number
         branch_index = string(i)
         push!(F_max,network_con["branch"][branch_index]["rate_a"])
     end  

    # the following constraints are the constraints in DCOPF model
    
     # generation level limit
     for i in 1:bus_number
         if i in beta_g
             @constraint(model_dc_benders_cut, bus_p[i] >= bus_p_min[i])
             @constraint(model_dc_benders_cut, bus_p[i] <= bus_p_max[i])
         else
             @constraint(model_dc_benders_cut, bus_p[i] == 0)
         end
     end

    # thermal limits
     for i in 1:branch_number
         @constraint(model_dc_benders_cut, flow[i] - F_max[i]<=0)
         @constraint(model_dc_benders_cut, -flow[i]- F_max[i]<=0)
     end 

    # KCL
     con1= []
     for i in 1:bus_number
         bus_index = string(i)
         push!(con1,@constraint(model_dc_benders_cut, flow_bus_matrix[i]- bus_d[i]== -bus_p[i] ))
     end

    # KVL
    con2 = []
    for i in 1:branch_number
        branch_index = string(i)    
        push!(con2,@constraint(model_dc_benders_cut, (-V0^2/network["branch"][branch_index]["br_x"])*line_matrix[i] == flow[i]))
    end 
 
    # Setting the Reference Bus (Bus 1) angles to 0
    @constraint(model_dc_benders_cut, voltage_phase[1] == 0)


    # objective function
    @objective(model_dc_benders_cut, Min,sum(gen_cost))
    optimize!(model_dc_benders_cut)
    
    status = termination_status(model_dc_benders_cut)
    solved_branch = 0
    if status == LOCALLY_SOLVED
        solved_branch = violate_branch_number
    else
        solved_branch = 0
    end
    
    return (value.(gen_p),value.(sum(gen_cost)))
end
# Out:
# run_dc_opf_with_benderscut (generic function with 1 method)

# %%
# this function is add all benders cuts to the master problem  
# the input is the dataset of the whole network , the critical contingency list, violation value list , lagrangian multiplier list, value of given bus
# the output is solution of basic dcopf model with a benders cut
# this function is almost the same with "run_dc_opf_with_benderscut",but it can add all cuts 
function run_dc_opf_all_benderscut(network,lagrangian_multiplier_set_list::Array,contingency_violation_list::Array,bus_p0_list::Array)
    
    bus_number = length(network["bus"])
    gen_number = length(network["gen"])
    branch_number = length(network["branch"])

    model_dc_benders_cut = Model(with_optimizer(Ipopt.Optimizer))
    @variable(model_dc_benders_cut, flow[1:branch_number])
    @variable(model_dc_benders_cut,voltage_phase[1:bus_number]) 
    @variable(model_dc_benders_cut, bus_p[1:bus_number],lower_bound=0)
    @variable(model_dc_benders_cut, gen_p[1:gen_number])
    @variable(model_dc_benders_cut, gen_cost[1:gen_number])
    @variable(model_dc_benders_cut, bus_add_cut[1:bus_number])



    beta_g = []
    for i in 1:gen_number
        gen_index = string(i)
        push!(beta_g,network["gen"][gen_index]["gen_bus"])
    end  

    bus_d = zeros(1,bus_number)
    for i in 1:length(network["load"])
        load_index = string(i)
        bus_name = network["load"][load_index]["load_bus"]
        bus_demand = network["load"][load_index]["pd"]
        bus_d[bus_name] = bus_demand
    end

    ab_l = []
    for i in 1:branch_number
        abl = []
        branch_index = string(i)
        push!(abl,network["branch"][branch_index]["f_bus"])
        push!(abl,network["branch"][branch_index]["t_bus"])
        push!(ab_l,abl)
    end

    A_bl=zeros(bus_number,branch_number)
    from_bus = 0
    to_bus = 0
    for i in 1:branch_number
        from_bus = ab_l[i][1]
        to_bus = ab_l[i][2]
        A_bl[(i-1)*bus_number+from_bus] = -1
        A_bl[(i-1)*bus_number+to_bus] = 1
    end 

    flow_bus_matrix = A_bl*flow

    line_matrix = A_bl'*voltage_phase
    V0 = 1

    bus_p_max = zeros(1,bus_number)
    for i in 1:gen_number
        gen_index = string(i)
        bus_name = network["gen"][gen_index]["gen_bus"]
        bus_produce_max = network["gen"][gen_index]["pmax"]
        bus_p_max[bus_name] = bus_produce_max
    end
    
    bus_p_min = zeros(1,bus_number)
    for i in 1:gen_number
        gen_index = string(i)
        bus_name = network["gen"][gen_index]["gen_bus"]
        bus_produce_min = network["gen"][gen_index]["pmin"]
        bus_p_min[bus_name] = bus_produce_min
    end

    #adding all bender cuts to the basic DCOPF model
    #iteration = length(effective_violate_branch_list)
    for i in 1:length(contingency_violation_list)
        vio_num = length(contingency_violation_list[i])
        for j in 1:vio_num
            #index= effective_violate_branch_list[i][j]
            @constraint(model_dc_benders_cut, sum((bus_p[b]-bus_p0_list[i][b])*lagrangian_multiplier_set_list[i][j][b] for b in 1:bus_number)+contingency_violation_list[i][j]<=0)
        end
    end 
    
   for i in 1:gen_number
       gen_index = string(i)
       bus_index = network["gen"][gen_index]["gen_bus"]
       @constraint(model_dc_benders_cut,gen_p[i] == bus_p[bus_index])
   end

   gen_cost_con=[]
   for i in 1:gen_number
       gen_index = string(i)
       push!(gen_cost_con,@constraint(model_dc_benders_cut,gen_cost[i] == network["gen"][gen_index]["cost"][1]*gen_p[i]^2+network["gen"][gen_index]["cost"][2]*gen_p[i]+network["gen"][gen_index]["cost"][3]))
   end    
    
    F_max = []
    for i in 1:branch_number
        branch_index = string(i)
        push!(F_max,network_con["branch"][branch_index]["rate_a"])
    end  

    for i in 1:bus_number
        if i in beta_g
            @constraint(model_dc_benders_cut, bus_p[i] >= bus_p_min[i])
            @constraint(model_dc_benders_cut, bus_p[i] <= bus_p_max[i])
        else
            @constraint(model_dc_benders_cut, bus_p[i] == 0)
        end
    end

    for i in 1:branch_number
        @constraint(model_dc_benders_cut, flow[i] - F_max[i]<=0)
        @constraint(model_dc_benders_cut, -flow[i]- F_max[i]<=0)
    end 

    con1= []
    for i in 1:bus_number
        bus_index = string(i)
        push!(con1,@constraint(model_dc_benders_cut, flow_bus_matrix[i]- bus_d[i]== -bus_p[i] ))
    end

    con2 = []
    for i in 1:branch_number
        branch_index = string(i)    
        push!(con2,@constraint(model_dc_benders_cut, (-V0^2/network["branch"][branch_index]["br_x"])*line_matrix[i] == flow[i]))
    end 

    # Setting the Reference Bus (Bus 1) angles to 0
    @constraint(model_dc_benders_cut, voltage_phase[1] == 0)


    # objective
    @objective(model_dc_benders_cut, Min,sum(gen_cost))

    optimize!(model_dc_benders_cut) 
    #return value.(gen_p)
    return (value.(gen_p),value.(voltage_phase))
end
# Out:
# run_dc_opf_all_benderscut (generic function with 1 method)

# %%
# There are threes step in this function
# the first step is to filter the contingency ,since some contingency cannot feasible for the basic SCOPF model
# the second step is to generated the benders cut from the filtered contingency and sovle the dcopf model with benders cut
# the third step is to check all the violation contingency and  generate the related vioaltion list 
# the output is to new dataset for the violation contingency if there still exists violation contingency
# the output is to tell that the optimal solution satisfied under all contingency if there is not violation contingency
# it include all the data that can be used for the next iteratio 
function check_recompute(lagrangian_multiplier_set_list0,violate_branch_list0,contingency_violation_list0,bus_p0)
    violate_list = []
    lagrangian_multiplier_set_list2 = []
    contingency_violation_list2 = []
    
    for i in 1:length(violate_branch_list0)
        if run_dc_scopf_contingency(case_data,violate_branch_list0[i]) == "infeasible"
        else
            push!(violate_list,i)
        end
    end
    println(violate_list)


    for i in violate_list
        push!(lagrangian_multiplier_set_list2,lagrangian_multiplier_set_list0[i])
        push!(contingency_violation_list2,contingency_violation_list0[i])
    end

    # compute the master problem with adding all benders cut
    network_basesolution = deepcopy(case_data)
    push!(bus_p0_list,bus_p0)
    push!(lm_list,lagrangian_multiplier_set_list2)
    push!(cv_list,contingency_violation_list2)
    push!(v_list,violate_list)

    # get the new value of power generation
    new = run_dc_opf_all_benderscut(case_data,lm_list,cv_list,bus_p0_list)
    new_result = collect(new)
    new_gen_p = new_result[1]
    new_voltage = new_result[2]
    println(new_gen_p)
    println(new_voltage)
    
    # use the new value to compute the sub problem
    network_con_revised = deepcopy(case_data)
    for i in 1:length(network_con_revised["gen"])
        gen_index = string(i)
        network_con_revised["gen"][gen_index]["pg"] = new_gen_p[i]
    end
    
    bus_p00 = zeros(1,bus_number)
    for i in 1:length(network_con_revised["gen"])
        gen_index = string(i)
        bus_name = network_con_revised["gen"][gen_index]["gen_bus"]
        bus_produce = new_gen_p[i]
        bus_p00[bus_name] = bus_produce
    end

    # find the all violation contingency with new generation value
    violation_details = benders_subproblem_test(network_con_revised)
    vd = collect(violation_details)
    violation_number = vd[1]
    violate_branch_list = vd[2]
    lagrangian_multiplier_set_list = vd[3]
    contingency_violation_list = vd[4]

    # find the effective violation contingency 
    violate_list = []
    for i in 1:length(violate_branch_list)
        if run_dc_scopf_contingency(case_data,violate_branch_list[i]) == "infeasible"
        else
            push!(violate_list,i)
        end
    end

    # print the result
    if length(violate_list) == 0
        return("we find the optimal solution to satisfy all branch contingencies for power flow violation")
    else
        info(LOGGER, "we DO NOT the optimal solution to satisfy all branch contingencies")
        println("viloation number:$(violation_number)")
        println("violate branch list:$(violate_branch_list)")
        println("contingency violation value list:$(contingency_violation_list)")
        return(lagrangian_multiplier_set_list,violate_branch_list,contingency_violation_list,bus_p00)        
    end
  
end
# Out:
# check_recompute (generic function with 1 method)

# %%
lm_list = []
cv_list = []
v_list = []
bus_p0_list = []
# Out:
# 0-element Array{Any,1}

# %%
# find all critical contingency 
network_con = deepcopy(network_base_con_dc_vio)
violation_details = benders_subproblem_test(network_con)

vd = collect(violation_details)
violation_number = vd[1]
violate_branch_list = vd[2]
lagrangian_multiplier_set_list = vd[3]
contingency_violation_list = vd[4]
if violation_number == 0
    info(LOGGER, "we find the optimal solution to satisfy all branch contingencies")
else
    info(LOGGER, "we DO NOT the optimal solution to satisfy all branch contingencies")
    println("viloation number:$(violation_number)")
    println("violate branch list:$(violate_branch_list)")
    println("contingency violation value list:$(contingency_violation_list)")
end

# set the given value of power generation at each bus for the first iteration
bus_number = length(case_data["bus"])
bus_p0 = zeros(1,bus_number)
for i in 1:gen_number
    gen_index = string(i)
    bus_name = case_data["gen"][gen_index]["gen_bus"]
    bus_produce = network_con["gen"][gen_index]["pg"]
    bus_p0[bus_name] = bus_produce
end
# Out:
# [info | GOC]: we DO NOT the optimal solution to satisfy all branch contingencies
# viloation number:9
# violate branch list:Any[7, 9, 113, 133, 134, 176, 177, 183, 184]
# contingency violation value list:Any[8.72162216783675, 8.72162216783682, 0.1200003479427077, 0.3424748919909132, 0.07752510800920404, 0.697728197410328, 1.3600003479426368, 3.6800003479426415, 0.40000034794268097]

# %%
# first iteration
iteration1 = check_recompute(lagrangian_multiplier_set_list,violate_branch_list,contingency_violation_list,bus_p0)
# Out:
# Any[1, 2, 3, 4, 6, 7]
# ┌ Warning: `with_optimizer` is deprecated. Adapt the following example to update your code:
# │ `with_optimizer(Ipopt.Optimizer)` becomes `Ipopt.Optimizer`.
# │   caller = run_dc_opf_all_benderscut(::Dict{String,Any}, ::Array{Any,1}, ::Array{Any,1}, ::Array{Any,1}) at In[129]:11
# └ @ Main .\In[129]:11
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     
0000000000000002, -1.0, 1.000000000000001, 0.999999999999998], [1.0000000000000018, 1.0000000000000013, 1.0000000000000016, 1.0000000000000013, 1.0000000000000013, 1.0000000000000013, 1.000000000000001, 1.000000000000001, 1.000000000000001, 1.000000000000001  …  0.9999999999999986, 0.9999999999999986, 0.9999999999999986, 0.9999999999999986, 1.0000000000000007, 1.0000000000000002, 1.0000000000000002, 0.9999999999999971, -1.0, 0.999999999999998]], Any[113, 134, 183, 184], Any[0.020204655806887753, 0.4199995800005789, 3.5397953466743366, 0.3999999999999824], [0.07010232666253799 0.0 … 0.0 0.0])

# %%
iteration1_parameters = collect(iteration1)
# second iteration
iteration2 = check_recompute(iteration1_parameters[1],iteration1_parameters[2],iteration1_parameters[3],iteration1_parameters[4])
# Out:
# Any[1]
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     1383
# Number of nonzeros in inequality constraint Jacobian.:     1306
# Number of nonzeros in Lagrangian Hessian.............:       54
#
# Total number of variables............................:      648
#                      variables with only lower bounds:      118
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      477
# Total number of inequality constraints...............:      487
#         inequality constraints with only lower bounds:       54
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      433
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 4.13e+01 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.6295256e+02 4.11e+01 5.61e+00  -1.0 5.31e+03  -4.0 3.87e-03 5.26e-03h  4
#    2  2.8485437e+02 4.09e+01 6.01e+00  -1.0 1.23e+04  -4.5 7.96e-03 6.02e-03f  1
#    3  8.9123929e+02 4.07e+01 5.47e+02  -1.0 8.61e+03  -5.0 6.26e-01 7.08e-03h  1
#    4  7.6662404e+03 4.27e+01 4.83e+02  -1.0 1.30e+04  -5.4 2.04e-02 7.92e-02h  1
#    5  1.4225354e+04 7.56e+01 4.32e+02  -1.0 1.35e+04  -5.9 1.24e-02 7.64e-02h  2
#    6  2.2846867e+04 1.20e+02 3.96e+02  -1.0 1.31e+04  -6.4 1.86e-01 1.02e-01h  1
#    7  3.5014396e+04 1.92e+02 3.21e+02  -1.0 1.27e+04  -6.9 4.01e-01 1.48e-01h  1
#    8  3.8291548e+04 1.89e+02 3.65e+02  -1.0 1.21e+04  -7.3 9.72e-01 4.25e-02h  1
#    9  1.2320207e+05 1.65e+02 8.23e+02  -1.0 1.18e+04  -7.8 8.63e-01 9.37e-01H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.2435670e+05 1.41e+02 7.01e+02  -1.0 1.16e+03  -8.3 7.60e-01 1.48e-01h  1
#   11  1.2437618e+05 1.40e+02 6.99e+02  -1.0 1.12e+03  -8.8 1.38e-03 2.95e-03h  1
#   12  1.2925333e+05 3.56e+01 1.76e+02  -1.0 2.74e+03  -9.2 1.34e-01 7.47e-01h  1
#   13  1.2926950e+05 3.52e+01 8.67e+02  -1.0 1.41e+03  -9.7 8.56e-01 1.16e-02h  1
#   14  1.2931437e+05 3.42e+01 1.13e+03  -1.0 8.99e+02 -10.2 2.68e-01 2.95e-02h  1
#   15  1.2957095e+05 2.87e+01 1.10e+03  -1.0 1.42e+03 -10.7 3.25e-01 1.82e-01h  1
#   16  1.3135730e+05 2.82e+01 3.49e+02  -1.0 9.58e+02 -11.2 7.71e-01 9.33e-01H  1
#   17  1.3140688e+05 2.11e+01 1.67e+04  -1.0 1.37e+02 -11.6 1.00e+00 2.57e-01h  1
#   18  1.3152314e+05 4.93e+00 9.41e+03  -1.0 1.03e+02 -12.1 1.00e+00 8.01e-01h  1
#   19  1.3153915e+05 2.35e+00 7.57e+04  -1.0 2.16e+01 -12.6 1.00e+00 5.27e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.